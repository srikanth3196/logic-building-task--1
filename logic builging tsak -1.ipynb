# %%
# User credentials
username = "admin"
password = "1234"

# Authentication logic
if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Login Successful

# %%
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for m in marks:
    if m >= 50:
        pass_count += 1
    else:
        fail_count += 1

print(f"Total Pass: {pass_count}")
print(f"Total Fail: {fail_count}")
# Out:
# Total Pass: 3
# Total Fail: 2

# %%
names = [" Alice ", "bob", " CHARLIE "]

# List comprehension for efficient cleaning
cleaned_names = [name.strip().lower() for name in names]

print("Cleaned List:", cleaned_names)
# Out:
# Cleaned List: ['alice', 'bob', 'charlie']

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

for msg in messages:
    length = len(msg)
    status = " - [FLAGGED: Long Message]" if length > 10 else ""
    print(f"Length: {length} | Content: {msg}{status}")
# Out:
# Length: 2 | Content: Hi
# Length: 23 | Content: Welcome to the platform - [FLAGGED: Long Message]
# Length: 2 | Content: OK

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

# Using the list count method for simplicity
error_count = logs.count("ERROR")

print(f"System Scan Complete. Total ERROR entries found: {error_count}")
# Out:
# System Scan Complete. Total ERROR entries found: 2
